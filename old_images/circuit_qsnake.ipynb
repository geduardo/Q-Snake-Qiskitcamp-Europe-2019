# %%
import numpy as np
from qiskit import *

# %%
q = QuantumRegister(1)

# Create a Quantum Circuit acting on a quantum register of n qubits
qc = QuantumCircuit(q)

# %%
diag = qc.draw(output="mpl")
diag.savefig("1.png", format="png")

# %%
qc.h(0)
diag = qc.draw(output="mpl")
diag.savefig("2.png", format="png")

# %%
qc.z(0)
diag = qc.draw(output="mpl")
diag.savefig("3.png", format="png")

# %%
qc.h(0)
diag = qc.draw(output="mpl")
diag.savefig("4.png", format="png")

# %%
#Cropping images
# !pip3 install Pillow
crp = [0,7,17,25]
from PIL import Image
for i in range(1,5):
    image = Image.open(str(i)+".png")
    w,h = image.size
    image.crop((20+crp[i-1],20,w,h-20)).save(str(i)+"c.png")
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/site-packages (6.1.0)

# %%
qc.measure(0,0)
qc.draw()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in _bit_argument_conversion(bit_representation, in_array)
#     283                 # circuit.h(0) -> circuit.h([qr[0]])
# --> 284                 ret = [in_array[bit_representation]]
#     285             elif isinstance(bit_representation, slice):
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# QiskitError                               Traceback (most recent call last)
# <ipython-input-19-0ad4a50c0474> in <module>
# ----> 1 qc.measure(0,0)
#       2 qc.draw()
#
# ~\Anaconda3\lib\site-packages\qiskit\circuit\measure.py in measure(self, qubit, cbit)
#      56             if cbit is not in this circuit or not creg.
#      57     """
# ---> 58     return self.append(Measure(), [qubit], [cbit])
#      59
#      60
#
# ~\Anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in append(self, instruction, qargs, cargs)
#     353
#     354         expanded_qargs = [self.qbit_argument_conversion(qarg) for qarg in qargs or []]
# --> 355         expanded_cargs = [self.cbit_argument_conversion(carg) for carg in cargs or []]
#     356
#     357         instructions = InstructionSet()
#
# ~\Anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in <listcomp>(.0)
#     353
#     354         expanded_qargs = [self.qbit_argument_conversion(qarg) for qarg in qargs or []]
# --> 355         expanded_cargs = [self.cbit_argument_conversion(carg) for carg in cargs or []]
#     356
#     357         instructions = InstructionSet()
#
# ~\Anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in cbit_argument_conversion(self, clbit_representation)
#     334             List(tuple): Where each tuple is a classical bit.
#     335         """
# --> 336         return QuantumCircuit._bit_argument_conversion(clbit_representation, self.clbits)
#     337
#     338     def append(self, instruction, qargs=None, cargs=None):
#
# ~\Anaconda3\lib\site-packages\qiskit\circuit\quantumcircuit.py in _bit_argument_conversion(bit_representation, in_array)
#     304                                                                     type(bit_representation)))
#     305         except IndexError:
# --> 306             raise QiskitError('Index out of range.')
#     307         except TypeError:
#     308             raise QiskitError('Type error handling %s (%s)' % (bit_representation,
#
# QiskitError: 'Index out of range.'

# %%
from qiskit.visualization import plot_bloch_vector

plot_bloch_vector([0,0,1], title='Intial state')

# %%
plot_bloch_vector([1,0,0], title='H gate')

# %%
plot_bloch_vector([-1,0,0], title='Z gate')

# %%
plot_bloch_vector([0,0,-1], title='H gate')
